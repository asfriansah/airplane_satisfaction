# %% [markdown]
# # General Process

# %% [markdown]
# **Background:**
#
# An airline conducts research to find out what factors influence passenger satisfaction.
#
# So it is hoped that in the future it can predict whether passengers are satisfied or dissatisfied based on these factors.
#
#
# **Dataset Overview:**
#
# *  *Customer Type*: is the type of customer/passenger loyal or disloyal?
# *  *Class*: type of cabin class whether economy, economy plus, or business class.
# *  *Gender*: gender (male or female).
# *  *Age*: the age of the passenger.
# *  *Type of Travel*: the type of trip whether business or personal.
# *  *Flight Distance*: flight mileage.
# *  *Checkin Service*: service when checking in with a score of 0 - 5.
# *  *Departure Delay in Minutes*: departure delay in minutes.
# *  *Arrival Delay in Minutes*: arrival delay in minutes.
# *  *Satisfaction*: passenger satisfaction (satisfied or dissatisfied)
#
#
# Feature '*satisfaction*' will be our target variable.

# %% [markdown]
# ## Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Digital Skola/Final Project/Dataset7_Airline_Satisfaction.csv')
#df = pd.read_csv('Dataset7_Airline_Satisfaction.csv')

# %%
df.sample(10).style.background_gradient(cmap='Dark2_r')
# Out:
# <style type="text/css">
# #T_7381c_row0_col3, #T_7381c_row0_col7, #T_7381c_row0_col8, #T_7381c_row1_col7, #T_7381c_row1_col8, #T_7381c_row2_col3, #T_7381c_row2_col8, #T_7381c_row3_col6, #T_7381c_row3_col7, #T_7381c_row3_col8, #T_7381c_row4_col5, #T_7381c_row5_col6, #T_7381c_row6_col3, #T_7381c_row6_col7, #T_7381c_row6_col8, #T_7381c_row7_col5, #T_7381c_row7_col7, #T_7381c_row7_col8, #T_7381c_row9_col7, #T_7381c_row9_col8 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_7381c_row0_col5, #T_7381c_row3_col5, #T_7381c_row5_col5, #T_7381c_row5_col7, #T_7381c_row8_col5 {
#   background-color: #66a61e;
#   color: #f1f1f1;
# }
# #T_7381c_row0_col6, #T_7381c_row1_col3, #T_7381c_row4_col6, #T_7381c_row7_col6 {
#   background-color: #7570b3;
#   color: #f1f1f1;
# }
# #T_7381c_row1_col5, #T_7381c_row2_col5, #T_7381c_row4_col7, #T_7381c_row9_col6 {
#   background-color: #e6ab02;
#   color: #000000;
# }
# #T_7381c_row1_col6, #T_7381c_row2_col6, #T_7381c_row4_col3, #T_7381c_row5_col3, #T_7381c_row6_col6, #T_7381c_row8_col6, #T_7381c_row8_col7, #T_7381c_row8_col8, #T_7381c_row9_col5 {
#   background-color: #1b9e77;
#   color: #f1f1f1;
# }
# #T_7381c_row2_col7, #T_7381c_row4_col8, #T_7381c_row6_col5, #T_7381c_row7_col3, #T_7381c_row9_col3 {
#   background-color: #a6761d;
#   color: #f1f1f1;
# }
# #T_7381c_row3_col3 {
#   background-color: #e7298a;
#   color: #f1f1f1;
# }
# #T_7381c_row5_col8, #T_7381c_row8_col3 {
#   background-color: #d95f02;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7381c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7381c_level0_col0" class="col_heading level0 col0" >Customer Type</th>
#       <th id="T_7381c_level0_col1" class="col_heading level0 col1" >Class</th>
#       <th id="T_7381c_level0_col2" class="col_heading level0 col2" >Gender</th>
#       <th id="T_7381c_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_7381c_level0_col4" class="col_heading level0 col4" >Type of Travel</th>
#       <th id="T_7381c_level0_col5" class="col_heading level0 col5" >Flight Distance</th>
#       <th id="T_7381c_level0_col6" class="col_heading level0 col6" >Checkin service</th>
#       <th id="T_7381c_level0_col7" class="col_heading level0 col7" >Departure Delay in Minutes</th>
#       <th id="T_7381c_level0_col8" class="col_heading level0 col8" >Arrival Delay in Minutes</th>
#       <th id="T_7381c_level0_col9" class="col_heading level0 col9" >satisfaction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7381c_level0_row0" class="row_heading level0 row0" >22710</th>
#       <td id="T_7381c_row0_col0" class="data row0 col0" >Loyal Customer</td>
#       <td id="T_7381c_row0_col1" class="data row0 col1" >Eco</td>
#       <td id="T_7381c_row0_col2" class="data row0 col2" >Female</td>
#       <td id="T_7381c_row0_col3" class="data row0 col3" >24</td>
#       <td id="T_7381c_row0_col4" class="data row0 col4" >Personal Travel</td>
#       <td id="T_7381c_row0_col5" class="data row0 col5" >2497</td>
#       <td id="T_7381c_row0_col6" class="data row0 col6" >4</td>
#       <td id="T_7381c_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_7381c_row0_col8" class="data row0 col8" >0.000000</td>
#       <td id="T_7381c_row0_col9" class="data row0 col9" >satisfied</td>
#     </tr>
#     <tr>
#       <th id="T_7381c_level0_row1" class="row_heading level0 row1" >89614</th>
#       <td id="T_7381c_row1_col0" class="data row1 col0" >Loyal Customer</td>
#       <td id="T_7381c_row1_col1" class="data row1 col1" >Business</td>
#       <td id="T_7381c_row1_col2" class="data row1 col2" >Female</td>
#       <td id="T_7381c_row1_col3" class="data row1 col3" >53</td>
#       <td id="T_7381c_row1_col4" class="data row1 col4" >Business travel</td>
#       <td id="T_7381c_row1_col5" class="data row1 col5" >1875</td>
#       <td id="T_7381c_row1_col6" class="data row1 col6" >5</td>
#       <td id="T_7381c_row1_col7" class="data row1 col7" >24</td>
#       <td id="T_7381c_row1_col8" class="data row1 col8" >15.000000</td>
#       <td id="T_7381c_row1_col9" class="data row1 col9" >satisfied</td>
#     </tr>
#     <tr>
#       <th id="T_7381c_level0_row2" class="row_heading level0 row2" >57082</th>
#       <td id="T_7381c_row2_col0" class="data row2 col0" >disloyal Customer</td>
#       <td id="T_7381c_row2_col1" class="data row2 col1" >Business</td>
#       <td id="T_7381c_row2_col2" class="data row2 col2" >Male</td>
#       <td id="T_7381c_row2_col3" class="data row2 col3" >22</td>
#       <td id="T_7381c_row2_col4" class="data row2 col4" >Business travel</td>
#       <td id="T_7381c_row2_col5" class="data row2 col5" >1919</td>
#       <td id="T_7381c_row2_col6" class="data row2 col6" >5</td>
#       <td id="T_7381c_row2_col7" class="data row2 col7" >27</td>
#       <td id="T_7381c_row2_col8" class="data row2 col8" >16.000000</td>
#       <td id="T_7381c_row2_col9" class="data row2 col9" >satisfied</td>
#     </tr>
#     <tr>
#       <th id="T_7381c_level0_row3" class="row_heading level0 row3" >69721</th>
#       <td id="T_7381c_row3_col0" class="data row3 col0" >Loyal Customer</td>
#       <td id="T_7381c_row3_col1" class="data row3 col1" >Business</td>
#       <td id="T_7381c_row3_col2" class="data row3 col2" >Female</td>
#       <td id="T_7381c_row3_col3" class="data row3 col3" >48</td>
#       <td id="T_7381c_row3_col4" class="data row3 col4" >Business travel</td>
#       <td id="T_7381c_row3_col5" class="data row3 col5" >2419</td>
#       <td id="T_7381c_row3_col6" class="data row3 col6" >2</td>
#       <td id="T_7381c_row3_col7" class="data row3 col7" >12</td>
#       <td id="T_7381c_row3_col8" class="data row3 col8" >0.000000</td>
#       <td id="T_7381c_row3_col9" class="data row3 col9" >dissatisfied</td>
#     </tr>
#     <tr>
#       <th id="T_7381c_level0_row4" class="row_heading level0 row4" >72139</th>
#       <td id="T_7381c_row4_col0" class="data row4 col0" >Loyal Customer</td>
#       <td id="T_7381c_row4_col1" class="data row4 col1" >Eco</td>
#       <td id="T_7381c_row4_col2" class="data row4 col2" >Female</td>
#       <td id="T_7381c_row4_col3" class="data row4 col3" >63</td>
#       <td id="T_7381c_row4_col4" class="data row4 col4" >Business travel</td>
#       <td id="T_7381c_row4_col5" class="data row4 col5" >741</td>
#       <td id="T_7381c_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_7381c_row4_col7" class="data row4 col7" >59</td>
#       <td id="T_7381c_row4_col8" class="data row4 col8" >32.000000</td>
#       <td id="T_7381c_row4_col9" class="data row4 col9" >dissatisfied</td>
#     </tr>
#     <tr>
#       <th id="T_7381c_level0_row5" class="row_heading level0 row5" >15594</th>
#       <td id="T_7381c_row5_col0" class="data row5 col0" >Loyal Customer</td>
#       <td id="T_7381c_row5_col1" class="data row5 col1" >Eco</td>
#       <td id="T_7381c_row5_col2" class="data row5 col2" >Male</td>
#       <td id="T_7381c_row5_col3" class="data row5 col3" >69</td>
#       <td id="T_7381c_row5_col4" class="data row5 col4" >Personal Travel</td>
#       <td id="T_7381c_row5_col5" class="data row5 col5" >2717</td>
#       <td id="T_7381c_row5_col6" class="data row5 col6" >2</td>
#       <td id="T_7381c_row5_col7" class="data row5 col7" >95</td>
#       <td id="T_7381c_row5_col8" class="data row5 col8" >159.000000</td>
#       <td id="T_7381c_row5_col9" class="data row5 col9" >dissatisfied</td>
#     </tr>
#     <tr>
#       <th id="T_7381c_level0_row6" class="row_heading level0 row6" >11938</th>
#       <td id="T_7381c_row6_col0" class="data row6 col0" >Loyal Customer</td>
#       <td id="T_7381c_row6_col1" class="data row6 col1" >Eco</td>
#       <td id="T_7381c_row6_col2" class="data row6 col2" >Male</td>
#       <td id="T_7381c_row6_col3" class="data row6 col3" >19</td>
#       <td id="T_7381c_row6_col4" class="data row6 col4" >Personal Travel</td>
#       <td id="T_7381c_row6_col5" class="data row6 col5" >1704</td>
#       <td id="T_7381c_row6_col6" class="data row6 col6" >5</td>
#       <td id="T_7381c_row6_col7" class="data row6 col7" >0</td>
#       <td id="T_7381c_row6_col8" class="data row6 col8" >0.000000</td>
#       <td id="T_7381c_row6_col9" class="data row6 col9" >dissatisfied</td>

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Check data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Customer Type               129880 non-null  object
#  1   Class                       129880 non-null  object
#  2   Gender                      129880 non-null  object
#  3   Age                         129880 non-null  int64
#  4   Type of Travel              129880 non-null  object
#  5   Flight Distance             129880 non-null  int64
#  6   Checkin service             129880 non-null  int64
#  7   Departure Delay in Minutes  129880 non-null  int64
#  8   Arrival Delay in Minutes    129487 non-null  float64
#  9   satisfaction                129880 non-null  object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 9.9+ MB

# %% [markdown]
# Notes:
#
# *   Our dataset consists of 129880 rows and 10 columns.
# *   float(1), int(4), object(5)
# *   Column 'Checkin service' seems to be an object, so we'll change it to type object

# %%
df['Checkin service'] = df['Checkin service'].astype(str)

# %%
df.describe(include='object').T
# Out:
#                   count unique              top    freq
# Customer Type    129880      2   Loyal Customer  106100
# Class            129880      3         Business   62160
# Gender           129880      2           Female   65899
# Type of Travel   129880      2  Business travel   89693
# Checkin service  129880      6                4   36481
# satisfaction     129880      2        satisfied   71087

# %%
df.describe().applymap('{0:.0f}'.format)
# Out:
#           Age Flight Distance Departure Delay in Minutes  \
# count  129880          129880                     129880
# mean       39            1981                         15
# std        15            1027                         38
# min         7              50                          0
# 25%        27            1359                          0
# 50%        40            1925                          0
# 75%        51            2544                         12
# max        85            6951                       1592
#
#       Arrival Delay in Minutes
# count                   129487
# mean                        15
# std                         38
# min                          0
# 25%                          0
# 50%                          0
# 75%                         13
# max                       1584

# %% [markdown]
# ## Inkonsistensi Data

# %% [markdown]
# Homogenize Data (For data with object type)

# %%
cols = df.columns

for i in cols:
  if df[i].dtypes == object :
    before = df[i].unique()
    df[i]=df[i].str.lower()
    print(f'Unique values columns {i} before : {before} --> after homogenize : {df[i].unique()}  \n')
# Out:
# Unique values columns Customer Type before : ['Loyal Customer' 'disloyal Customer'] --> after homogenize : ['loyal customer' 'disloyal customer']
#
# Unique values columns Class before : ['Eco' 'Business' 'Eco Plus'] --> after homogenize : ['eco' 'business' 'eco plus']
#
# Unique values columns Gender before : ['Female' 'Male'] --> after homogenize : ['female' 'male']
#
# Unique values columns Type of Travel before : ['Personal Travel' 'Business travel'] --> after homogenize : ['personal travel' 'business travel']
#
# Unique values columns satisfaction before : ['satisfied' 'dissatisfied'] --> after homogenize : ['satisfied' 'dissatisfied']

# %% [markdown]
# ## Missing Value (Null & NA)

# %%
df.isna().sum()
# Out:
# Customer Type                   0
# Class                           0
# Gender                          0
# Age                             0
# Type of Travel                  0
# Flight Distance                 0
# Checkin service                 0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      393
# satisfaction                    0
# dtype: int64

# %% [markdown]
# Notes : Arrival Delay in Minutes has 393 missing value (NA)

# %%
med = df['Arrival Delay in Minutes'].median()
df.fillna(med, inplace=True)
df.isna().sum()
# Out:
# Customer Type                 0
# Class                         0
# Gender                        0
# Age                           0
# Type of Travel                0
# Flight Distance               0
# Checkin service               0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# satisfaction                  0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysist

# %%
# Countplot function to perform Univariate analysis
def plotUnivariate(datax):
  Total = len(df[datax])
  ax = sns.countplot(x = datax, data = df, palette = 'mako')
  ax.set_facecolor('#faf9f4')
  #plt.rcParams['font.size'] = '14'
  for p in ax.patches:
      percentage = f'{100 * p.get_height() / Total:.1f}%\n'
      x = p.get_x() + p.get_width() / 2
      y = p.get_height()
      
      ax.annotate(percentage, (x, y), ha='center', va='center', fontsize=11)

  ax.set_xlabel(datax, fontsize=14)
  ax.set_ylabel('Count',fontsize=14)
  plt.title(f'{datax} Distribution', fontsize=14)

# %%
# Countplot function to perform Bivariate analysis
def plotBivariate(datax,datay):
  Total = len(df[datax])
  ax = sns.countplot(x = datax, data = df, hue= datay, palette = 'mako')
  ax.set_facecolor('#faf9f4')
  #plt.rcParams['font.size'] = '14'
  for p in ax.patches:
      percentage = f'{100 * p.get_height() / Total:.1f}%\n'
      x = p.get_x() + p.get_width() / 2
      y = p.get_height()
      
      ax.annotate(percentage, (x, y), ha='center', va='center', fontsize=11)

  ax.set_xlabel(datax, fontsize=14)
  ax.set_ylabel('Count',fontsize=14)
  plt.title(f'{datax} Vs {datay}', fontsize=14)

# %% [markdown]
# ## Univariate Analysist

# %% [markdown]
# ### Categorical

# %%
cols = df.columns
col_obj = []
for i in cols:
  if df[i].dtypes == object :
    print(f'{df[i].value_counts()} + \n')
    col_obj.append(i)

plt.figure(figsize=(15, 10))
plt.subplots_adjust(hspace=0.3,wspace=0.3)

for n, col in enumerate(col_obj):
    ax = plt.subplot(2, 3, n + 1)
    plotUnivariate(col)

plt.show
# Out:
# loyal customer       106100
# disloyal customer     23780
# Name: Customer Type, dtype: int64 +
#
# business    62160
# eco         58309
# eco plus     9411
# Name: Class, dtype: int64 +
#
# female    65899
# male      63981
# Name: Gender, dtype: int64 +
#
# business travel    89693
# personal travel    40187
# Name: Type of Travel, dtype: int64 +
#
# 4    36481
# 3    35538
# 5    27005
# 2    15486
# 1    15369
# 0        1
# Name: Checkin service, dtype: int64 +
#
# satisfied       71087
# dissatisfied    58793
# Name: satisfaction, dtype: int64 +
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
# *    There is a significant difference between satisfied and dissatisfied passengers around 12.294.
# *    As we can see, the number of men and women is almost the same, there are only slight differences.
# *    There is a very big difference, where the number of loyal customers is far more than disloyal.
# *    The number of Business Travel is much more than Personal Travel. That means we work more with Customers at the Business Layer.
# *    Customers prefer business or economy class over economy plus class
# *  Most passengers give a value of 3-5 for check-in services. This means that passengers are quite satisfied with the check-in service.

# %% [markdown]
# ### Numeric

# %%
df['Age'].describe()
# Out:
# count    129880.000000
# mean         39.427957
# std          15.119360
# min           7.000000
# 25%          27.000000
# 50%          40.000000
# 75%          51.000000
# max          85.000000
# Name: Age, dtype: float64

# %%
sns.displot(data = df['Age'], palette='mako', kde=True, height = 5)
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %% [markdown]
# Notes :
#
# *  The average age of passengers is around 39 years
# *  Only a few children were passengers
# *  Most of the passengers are between 24 - 54 years old

# %%
df['Flight Distance'].describe()
# Out:
# count    129880.000000
# mean       1981.409055
# std        1027.115606
# min          50.000000
# 25%        1359.000000
# 50%        1925.000000
# 75%        2544.000000
# max        6951.000000
# Name: Flight Distance, dtype: float64

# %%
sns.displot(data = df['Flight Distance'], palette='mako', kde=True, height = 5)
plt.title('Distribution of Flight Distance')
# Out:
# Text(0.5, 1.0, 'Distribution of Flight Distance')

# %% [markdown]
# Notes:
#
# *   Average of flight distances is 1981 km. That means we don't spend a lot of time in the air.
# *   From the diagram above shows the most frequent flights with a range of 1000 - 3000 km

# %%
df[['Age','Flight Distance']].agg(['skew','kurtosis']).transpose()
# Out:
#                      skew  kurtosis
# Age             -0.003606 -0.719140
# Flight Distance  0.466748  0.364306

# %% [markdown]
# Notes :
#
# *   Age has a skew of less than 0, the distribution is slightly negative or skewed to the left, which means the mean < median.
# *   Flight Distance has a skew of more than 0, the distribution tends to be positive or skewed to the right, which means the mean > median.
# *   All of them have a kurtosis of less than 3, which is called platykurtic, which means they tend to produce fewer and less extreme outliers than the normal distribution.

# %%
df[['Departure Delay in Minutes','Arrival Delay in Minutes']].describe().applymap('{0:.0f}'.format)
# Out:
#       Departure Delay in Minutes Arrival Delay in Minutes
# count                     129880                   129880
# mean                          15                       15
# std                           38                       38
# min                            0                        0
# 25%                            0                        0
# 50%                            0                        0
# 75%                           12                       13
# max                         1592                     1584

# %%
fig = plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.boxplot(x=df["Departure Delay in Minutes"])
plt.subplot(1,2,2)
sns.boxplot(x=df["Arrival Delay in Minutes"])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
#
# *   Average of Departure Delay is 14 Minutes, and Arrival Delays about 15 minutes.
#
# *   Between arrival and departure delays have a similar boxplot diagram, meaning that these two features have a significant correlation. Any delay in departure will cause a delay in arrival

# %%
df.describe().applymap('{0:.0f}'.format).T
# Out:
#                              count  mean   std min   25%   50%   75%   max
# Age                         129880    39    15   7    27    40    51    85
# Flight Distance             129880  1981  1027  50  1359  1925  2544  6951
# Departure Delay in Minutes  129880    15    38   0     0     0    12  1592
# Arrival Delay in Minutes    129880    15    38   0     0     0    13  1584

# %% [markdown]
# ## Bivariate Analysist

# %% [markdown]
# ### Predictor Variable VS Target Variable

# %% [markdown]
# #### Categorical

# %%
cols = ['Customer Type','Class','Gender','Type of Travel','Checkin service']

plt.figure(figsize=(15,15))
plt.subplots_adjust(hspace=0.3,wspace=0.3)

for n, col in enumerate(cols):
    # add a new subplot iteratively
    ax = plt.subplot(3, 2, n + 1)
    plotBivariate(col,'satisfaction')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
#
# *   It can be seen that Disloyal Customers have more dissatisfaction and it makes sense because they are not loyal customers.
# But in Loyal Customers also have more dissatisfaction and it becomes a problem. We must know the cause of this problem occurs.
# *   For flights with economy class, more passengers are dissatisfied. We have to find out what causes it.
# *   Flights with business class, the average passenger is satisfied.
# *   For female passengers, they are more satisfied with their flights, in contrast to men who are dissatisfied.
# *   We're not good at Personal Travel because there are more dissatisfied customers than satisfied customers.  That could explain why there are more Business Travel than Personal.
# *   In Business Travel, there are more satisfied than dissatisfied customers and that's good, very good, but still the number of dissatisfied customers is not small. So we have to find out what causes it.
# *   Checkin service with a score below 3 on average feels dissatisfied while a score above 3 feels satisfied

# %% [markdown]
# #### Numeric

# %%
col =['Flight Distance','Age','Departure Delay in Minutes','Arrival Delay in Minutes']
plt.figure(figsize=(10,10))
for i in col:
  sns.displot(df,x=i, hue="satisfaction", kind="kde")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
#
# *   For flight distances < 1300 most passengers are satisfied.
# *   Flights distance 1300 - 2500 most passengers are dissatisfied.
# *   And if the flight distance > 2500, the passengers are satisfied.
# *   Passengers aged < 40 years are more dissatisfied, although not too significant.
# *   But if the age of 40 - 60 years significantly satisfied.
# *   And if the age > 60 years most feel dissatisfied.
# *   Delays in departure and arrival have the same pattern. Most of the delay occurs between 0 - 50 minutes. To see passenger satisfaction, we have to look at other features.

# %% [markdown]
# ## Other Variable VS Customer Type

# %% [markdown]
# #### Categorical

# %%
cols = ['Class','Gender','Type of Travel','Checkin service',]

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.3,wspace=0.3)

for n, col in enumerate(cols):
    # add a new subplot iteratively
    ax = plt.subplot(2, 2, n + 1)
    if n <= 3:
      plotBivariate(col,'Customer Type')
      
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Numeric

# %%
col =['Flight Distance','Age','Departure Delay in Minutes','Arrival Delay in Minutes']
plt.figure(figsize=(10,10))
for i in col:
  sns.displot(df,x=i, hue="Customer Type", kind="kde")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
#
# *   Loyal customers prefer business class for their flights, while disloyal customers prefer economy class. This is one of the reasons why in economy class there are many dissatisfied customers.
# *   Both of them make more business travel than personal travel. Almost all disloyal customers do business travel.
# *   For disloyal customers, flight distance does not affect the number of satisfied and dissatisfied is almost the same.
# *   Meanwhile, loyal customers feel a little more satisfied for long-distance flights.
# *   Loyal customers who feel dissatisfied are mostly felt by those under 40 years of age.
# *   Both loyal and disloyal customer feel satisfy when delay is not beyond 12.5 Minutes.

# %% [markdown]
# ## Other Variable VS Class

# %% [markdown]
# #### Categorical

# %%
cols = ['Gender','Type of Travel','Checkin service']

plt.figure(figsize=(15, 10))
plt.subplots_adjust(hspace=0.2,wspace=0.3)

for n, col in enumerate(cols):
    # add a new subplot iteratively
    ax = plt.subplot(2, 2, n + 1)
    if n <= 2:
      plotBivariate(col,'Class')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
#
# *   There are still many customers with business travel who get economy class. This is the reason why many business travel customers are still dissatisfied. Business travel customers should get business class.

# %% [markdown]
# #### Numeric

# %%
col =['Flight Distance','Age','Departure Delay in Minutes','Arrival Delay in Minutes']
plt.figure(figsize=(10,10))
for i in col:
  sns.displot(df,x=i, hue="Class", kind="kde")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes :
#
# *   Customers in economy class are vulnerable to feeling dissatisfied when flying long distances.
# *   As long as the delay does not exceed 12.5 minutes, passengers in all classes are satisfied.

# %% [markdown]
# ## Multivariat Analysis

# %% [markdown]
# For the purposes of multivariate analysis, the satisfaction feature is converted to numeric.

# %%
# For the purposes of multivariate analysis, the satisfaction feature is converted to numeric.
mapping_satisfaction = {'dissatisfied' : 0, 'satisfied' : 1}
df['satisfaction'] = df['satisfaction'].map(mapping_satisfaction)
df['satisfaction'] = df['satisfaction'].astype(int)

# %% [markdown]
# ### Categorical

# %% [markdown]
# ### Other Features vs Gender & Satisfaction

# %%
cols = ['Class','Type of Travel','Checkin service','Customer Type']

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.2,wspace=0.3)

for col in cols:
    sns.catplot(data=df, x=col, y="satisfaction", col="Gender",kind="bar", height=4)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes:
#
# *   The average woman is satisfied for each flight cabin class. On the other hand, men are only satisfied if they are in business class
# *   Women prefer personal travel over business purposes, in contrast to men who prefer their travels for business.
# *   Loyal customers of the female gender tend to be satisfied with their flights, in contrast to males who are more dissatisfied with their flights. Meanwhile, for disloyal customers, both male and frmale were equally dissatisfied.

# %% [markdown]
# ### Other Features vs Customer Type & Satisfaction

# %%
cols = ['Class','Type of Travel','Checkin service']

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.2,wspace=0.3)

for col in cols:
    sns.catplot(data=df, x=col, y="satisfaction", col="Customer Type",kind="bar", height=4)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes:
#
# *   Loyal customers tend to be satisfied if their flights are in business class and only some are satisfied if they are in economy class. Meanwhile, disloyal customers tend to feel dissatisfied when they are in any class.
# *   Loyal customers who travel for business are mostly satisfied compared to those who travel for personal use.

# %% [markdown]
# ### Other Features vs Class & Satisfaction

# %%
cols = ['Type of Travel','Checkin service']

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.2,wspace=0.3)

for col in cols:
    sns.catplot(data=df, x=col, y="satisfaction", col="Class",kind="bar", height=4)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Notes:
#
# *   Passengers traveling on business are satisfied if they use business class, and feel dissatisfied if they are in economy or economy plus class.
# *   Passengers who take personal trips do not care about the cabin class they choose, tend to be balanced between satisfied and dissatisfied.

# %% [markdown]
# ### Other Features vs Type of Travel & Satisfaction

# %%
cols = ['Gender','Customer Type','Class','Checkin service']

plt.figure(figsize=(15, 20))
plt.subplots_adjust(hspace=0.2,wspace=0.3)

for col in cols:
    sns.catplot(data=df, x=col, y="satisfaction", col="Type of Travel",kind="bar", height=4)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(df, hue='satisfaction', palette='husl')

# %% [markdown]
# ## Mapping categorical data into numeric

# %%
mapping_cust = {'loyal customer':1,'disloyal customer':0}
df['Customer Type'] = df['Customer Type'].map(mapping_cust)
df['Customer Type'] = df['Customer Type'].astype(int)

# %%
mapping_class = {'business':2,'eco':0,'eco plus':1}
df['Class'] = df['Class'].map(mapping_class)
df['Class'] = df['Class'].astype(int)

# %%
mapping_gender = {'male':0,'female':1}
df['Gender'] = df['Gender'].map(mapping_gender)
df['Gender'] = df['Gender'].astype(int)

# %%
mapping_type = {'personal travel':0,'business travel':1}
df['Type of Travel'] = df['Type of Travel'].map(mapping_type)
df['Type of Travel'] = df['Type of Travel'].astype(int)

# %%
df['Arrival Delay in Minutes'] = df['Arrival Delay in Minutes'].astype(int)

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Separating independent variables  and dependent variables

# %%
X = df.drop(['satisfaction'],axis = 1)
y = df['satisfaction']

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Pearson Correlation

# %%
# Feature selection using Pearson Correlation
ax = sns.heatmap(df.corr(), cmap = "coolwarm", annot=False, linewidth=2)

# %% [markdown]
# Notes :
#
# *   The arrival and departure columns show a strong correlation or relationship between two or more independent variables (multicolinearity), so we can delete one of these columns.

# %%
correlation = (pd.DataFrame(abs(df.corr()).satisfaction))
correlation.sort_values(by='satisfaction', ascending=False).style.background_gradient(cmap='coolwarm_r')
# Out:
# <style type="text/css">
# #T_48227_row0_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_48227_row1_col0 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_48227_row2_col0 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_48227_row3_col0 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_48227_row4_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_48227_row5_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_48227_row6_col0 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_48227_row7_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_48227_row8_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_48227" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48227_level0_col0" class="col_heading level0 col0" >satisfaction</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48227_level0_row0" class="row_heading level0 row0" >satisfaction</th>
#       <td id="T_48227_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row1" class="row_heading level0 row1" >Class</th>
#       <td id="T_48227_row1_col0" class="data row1 col0" >0.305535</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row2" class="row_heading level0 row2" >Customer Type</th>
#       <td id="T_48227_row2_col0" class="data row2 col0" >0.292592</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row3" class="row_heading level0 row3" >Gender</th>
#       <td id="T_48227_row3_col0" class="data row3 col0" >0.212236</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row4" class="row_heading level0 row4" >Age</th>
#       <td id="T_48227_row4_col0" class="data row4 col0" >0.117971</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row5" class="row_heading level0 row5" >Type of Travel</th>
#       <td id="T_48227_row5_col0" class="data row5 col0" >0.109239</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row6" class="row_heading level0 row6" >Arrival Delay in Minutes</th>
#       <td id="T_48227_row6_col0" class="data row6 col0" >0.080487</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row7" class="row_heading level0 row7" >Departure Delay in Minutes</th>
#       <td id="T_48227_row7_col0" class="data row7 col0" >0.073909</td>
#     </tr>
#     <tr>
#       <th id="T_48227_level0_row8" class="row_heading level0 row8" >Flight Distance</th>
#       <td id="T_48227_row8_col0" class="data row8 col0" >0.039224</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### KBest using F-test

# %%
# Feature Selection using F-test
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
clf = SelectKBest(f_classif, k=8)
clf = clf.fit(X, y)
clf.get_feature_names_out()
# Out:
# array(['Customer Type', 'Class', 'Gender', 'Age', 'Type of Travel',
#        'Checkin service', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'], dtype=object)

# %% [markdown]
# ### Feature Selection using Ridge regression algorithm model

# %%
# Feature Selection using Ridge regression algorithm model 
from sklearn.linear_model import RidgeCV

ridge = RidgeCV(alphas=np.logspace(-6, 6, num=5)).fit(X, y)
importance = np.abs(ridge.coef_)
feature_names = np.array(X.columns)

#ploting Feature importances vs coefficients
plt.figure(figsize=(10,6))
ax = plt.subplot()
plt.bar(height=importance, x=feature_names)
plt.title("Feature importances via coefficients")
ax.set_xlabel('Features', fontsize=14)
ax.set_ylabel('Coefficients',fontsize=14)
ax.tick_params(axis='x', rotation=55)

plt.show()

# %% [markdown]
# Notes :
#
# *   From the three feature selection methods above, the results are not much different. The 3 features that don't matter much are Arrival Delay in Minutes, Departure Delay in Minutes, and Flight Distance.
# *   Flight Distance being the least influential feature.
# *   The arrival and departure columns show a strong correlation or relationship between two or more independent variables (multicolinearity), so we can delete one of these columns.
# *   Therefore we will remove the flight distance and Departure Delay in Minutes.

# %%
# Remove 'Departure Delay in Minutes' to avoid multicollinearity
X.drop(['Departure Delay in Minutes'],axis=1,inplace=True)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Customer Type             129880 non-null  int64
#  1   Class                     129880 non-null  int64
#  2   Gender                    129880 non-null  int64
#  3   Age                       129880 non-null  int64
#  4   Type of Travel            129880 non-null  int64
#  5   Flight Distance           129880 non-null  int64
#  6   Checkin service           129880 non-null  object
#  7   Arrival Delay in Minutes  129880 non-null  int64
# dtypes: int64(7), object(1)
# memory usage: 7.9+ MB

# %% [markdown]
# ## Train Test Split

# %%
from collections import Counter
from sklearn.model_selection import train_test_split,cross_val_score,RandomizedSearchCV
X_train ,X_test,y_train ,y_test = train_test_split(X,y,test_size =0.1 , random_state=42 , stratify=y)

# %% [markdown]
# ## Scalling

# %%
# Using Standard Scalling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X.columns)

# %%
# Save the scaler for later use when deploying the model
import pickle
pickle.dump(scaler, open('scaler.pkl','wb'))

# %% [markdown]
# ## Run All Model Training

# %%
from sklearn.linear_model import LogisticRegression ,SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import make_scorer, r2_score

# %%
models = {'Logistic Regression': LogisticRegression(),
         'KNN': KNeighborsClassifier(),
         'Decision Tree': DecisionTreeClassifier(),
         'Random Forest': RandomForestClassifier(),
         'Gradient Boosting Classifier':GradientBoostingClassifier(),
         'Stochastic Gradien Descent': SGDClassifier(),
         'Naive Bayes': GaussianNB(),
         'xgb Classifier': XGBClassifier(),
         'Bagging Classifier': BaggingClassifier(),
         'Boosting': AdaBoostClassifier(),
         'MLP': MLPClassifier(),
         'LDA': LinearDiscriminantAnalysis(),
         'QDA': QuadraticDiscriminantAnalysis()}

# %%
def fit_score(models, X_train, X_test, y_train, y_test):

    # Define the number of folds for cross-validation
    num_folds = 10

    # Split the dataset into folds
    kfold = KFold(n_splits=num_folds, shuffle=True)
    np.random.seed(42)
    model_scores = {}
    for name, model in models.items():
        model.fit(X_train, y_train)
        model_scores[name] = cross_val_score(model,X_train,y_train,scoring='accuracy',cv=kfold, error_score='raise').mean()

    return model_scores

# %%
model_scores = fit_score(models,X_train_scaled,X_test_scaled,y_train,y_test)
model_scores
# Out:
# {'Logistic Regression': 0.7510351195486153,
#  'KNN': 0.7945968151935378,
#  'Decision Tree': 0.738331050644516,
#  'Random Forest': 0.788907623809858,
#  'Gradient Boosting Classifier': 0.8106799378035296,
#  'Stochastic Gradien Descent': 0.7551415004828957,
#  'Naive Bayes': 0.7182784271965461,
#  'xgb Classifier': 0.8158043698970194,
#  'Bagging Classifier': 0.7823032943682072,
#  'Boosting': 0.7430877143089865,
#  'MLP': 0.8152739866929061,
#  'LDA': 0.7506331279852576,
#  'QDA': 0.7803785182284442}

# %% [markdown]
# Notes :
#
# *   XGB Classifier has the best accuracy among other models (0.816/ 81,6 %).
#
# *   The accuracy obtained is quite good. So we can choose the XGB Classifier model as our prediction model.

# %%
a = []
b = []
for i in model_scores:
  a.append(i)
  b.append(model_scores[i])

plt.barh(a,b)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sco = pd.DataFrame({'Model':a, 'Score Accuracy': b})
sco.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_73958_row0_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_73958_row1_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_73958_row2_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_73958_row3_col1 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_73958_row4_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_73958_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_73958_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_73958_row7_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_73958_row8_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_73958_row9_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_73958_row10_col1 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_73958_row11_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_73958_row12_col1 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# </style>
# <table id="T_73958" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73958_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_73958_level0_col1" class="col_heading level0 col1" >Score Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73958_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73958_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_73958_row0_col1" class="data row0 col1" >0.751035</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73958_row1_col0" class="data row1 col0" >KNN</td>
#       <td id="T_73958_row1_col1" class="data row1 col1" >0.794597</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73958_row2_col0" class="data row2 col0" >Decision Tree</td>
#       <td id="T_73958_row2_col1" class="data row2 col1" >0.738331</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73958_row3_col0" class="data row3 col0" >Random Forest</td>
#       <td id="T_73958_row3_col1" class="data row3 col1" >0.788908</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73958_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_73958_row4_col1" class="data row4 col1" >0.810680</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73958_row5_col0" class="data row5 col0" >Stochastic Gradien Descent</td>
#       <td id="T_73958_row5_col1" class="data row5 col1" >0.755142</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_73958_row6_col0" class="data row6 col0" >Naive Bayes</td>
#       <td id="T_73958_row6_col1" class="data row6 col1" >0.718278</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_73958_row7_col0" class="data row7 col0" >xgb Classifier</td>
#       <td id="T_73958_row7_col1" class="data row7 col1" >0.815804</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_73958_row8_col0" class="data row8 col0" >Bagging Classifier</td>
#       <td id="T_73958_row8_col1" class="data row8 col1" >0.782303</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_73958_row9_col0" class="data row9 col0" >Boosting</td>
#       <td id="T_73958_row9_col1" class="data row9 col1" >0.743088</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_73958_row10_col0" class="data row10 col0" >MLP</td>
#       <td id="T_73958_row10_col1" class="data row10 col1" >0.815274</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_73958_row11_col0" class="data row11 col0" >LDA</td>
#       <td id="T_73958_row11_col1" class="data row11 col1" >0.750633</td>
#     </tr>
#     <tr>
#       <th id="T_73958_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_73958_row12_col0" class="data row12 col0" >QDA</td>
#       <td id="T_73958_row12_col1" class="data row12 col1" >0.780379</td>
#     </tr>
#   </tbody>
# </table>

# %%
xgboost = XGBClassifier()
xgboost.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
MLP = MLPClassifier()
MLP.fit(X_train_scaled, y_train)
# Out:
# MLPClassifier()

# %%
import pickle
pickle.dump(xgboost, open('xgboost2.pkl','wb'))

# %%
y_pred_xgb = xgboost.predict(X_test_scaled)

# %%
y_pred_mlp = MLP.predict(X_test_scaled)

# %% [markdown]
# ### Confusion Matrix for XGBoost & MLP

# %%
from sklearn.metrics import confusion_matrix, classification_report

plt.figure(figsize=(15,6))
ax =plt.subplot(1,2,1)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_pred_xgb)) , annot=True, fmt='.0f')
plt.title('Confusion Matrix XGBoost')

ax =plt.subplot(1,2,2)
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_pred_mlp)) , annot=True, fmt='.0f')
plt.title('Confusion Matrix MLP')

plt.show()

# %%
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81      5879
#            1       0.85      0.82      0.83      7109
#
#     accuracy                           0.82     12988
#    macro avg       0.82      0.82      0.82     12988
# weighted avg       0.82      0.82      0.82     12988

# %%
print(classification_report(y_test, y_pred_mlp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81      5879
#            1       0.86      0.80      0.83      7109
#
#     accuracy                           0.82     12988
#    macro avg       0.82      0.82      0.82     12988
# weighted avg       0.82      0.82      0.82     12988

# %% [markdown]
# ### ROC & AUC for XGBoost & MLP

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# XGBoost
xgb_probs = xgboost.predict_proba(X_test_scaled)
random_probs_xgb = [0 for _ in range(len(y_test))]

# MLP
mlp_probs = MLP.predict_proba(X_test_scaled)
random_probs_mlp = [0 for _ in range(len(y_test))]

# %%
xgb_probs = xgb_probs[:,1]
mlp_probs = mlp_probs[:,1]

# %%
# Calculate AUC for a random model
random_auc = roc_auc_score(y_test, random_probs_xgb)
 
# Calculate AUC for a XGBoost classifier
xgb_auc = roc_auc_score(y_test, xgb_probs)
# Calculate AUC for a MLP classifier
mlp_auc = roc_auc_score(y_test, mlp_probs)
 
# Show the result
print('Random Prediction : AUCROC = %.3f' % (random_auc))
print('XGBoost : AUCROC = %.3f' % (xgb_auc))
print('MLP : AUCROC = %.3f' % (mlp_auc))
# Out:
# Random Prediction : AUCROC = 0.500
# XGBoost : AUCROC = 0.897
# MLP : AUCROC = 0.894

# %%
# Stores the values ​​needed to create the ROC curve (false positive rate, true positive rate) for XGBoost
random_fpr, random_tpr, _ = roc_curve(y_test, random_probs_xgb)
xgb_fpr, xgb_tpr, _ = roc_curve(y_test, xgb_probs)
# Stores the values ​​needed to create the ROC curve (false positive rate, true positive rate) for MLP
random_fpr, random_tpr, _ = roc_curve(y_test, random_probs_mlp)
mlp_fpr, mlp_tpr, _ = roc_curve(y_test, mlp_probs)
# Plot ROC curve
plt.plot(random_fpr, random_tpr, marker='.', label='Random : (AUCROC = %.3f)' % random_auc)
plt.plot(xgb_fpr, xgb_tpr, marker='.', label='XGBoost : (AUCROC = %.3f)' % xgb_auc)
plt.plot(mlp_fpr, mlp_tpr, marker='.', label='MLP : (AUCROC = %.3f)' % mlp_auc)
 
plt.title('ROC Plot')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# Notes:
#
# Between XGBoost and MLP have almost the same AUC value. Both show pretty good model performance. Very little difference between the two models

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Find the best estimator using cross validation

# %% [markdown]
# ### Hyperparameter Tuning for XGBoost

# %%
np.random.seed(42)
params = {"n_estimators": [50,100,200, 300] ,
 'max_depth': [1,3,18],
        'gamma': [1,9],
        'reg_alpha' : [40,180,1],
        'reg_lambda' :[0,1],}


xg = RandomizedSearchCV(XGBClassifier(),
                                param_distributions=params,
                                cv=4,
                                n_iter=100,
                                verbose=1,
                              refit=True,
                                n_jobs=-1
                               )

xg.fit(X_train_scaled, y_train)
xg.best_params_
# Out:
# Fitting 4 folds for each of 100 candidates, totalling 400 fits
# {'reg_lambda': 1,
#  'reg_alpha': 1,
#  'n_estimators': 50,
#  'max_depth': 18,
#  'gamma': 9}

# %%
xg.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=9, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=18, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xg.best_score_
# Out:
# 0.8179516134551551

# %%
model = XGBClassifier(reg_lambda = 1, reg_alpha = 1, n_estimators = 50, max_depth = 18, gamma = 9)
model.fit(X_train_scaled, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=9, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=18, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred = model.predict(X_test_scaled)

# %% [markdown]
# ### Hyperparameter Tuning for MLP

# %%
mlp = MLPClassifier(max_iter=100)

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train_scaled, y_train)
# Out:
# GridSearchCV(cv=3, estimator=MLPClassifier(max_iter=100), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.05],
#                          'hidden_layer_sizes': [(50, 50, 50), (50, 100, 50),
#                                                 (100,)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']})

# %%
# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.811 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.815 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.809 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.810 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.814 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.811 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.814 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.805 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.815 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.806 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.814 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.809 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.816 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.809 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.816 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.809 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.814 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.809 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.813 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.805 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.813 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.805 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.813 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.812 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.816 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.813 (+/-0.002) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.814 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.813 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.814 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.813 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.808 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.813 (+/-0.003) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.809 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.816 (+/-0.006) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.813 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.815 (+/-0.003) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.812 (+/-0.005) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.003) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.814 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.816 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.813 (+/-0.003) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.817 (+/-0.005) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 100, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.807 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.814 (+/-0.002) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.807 (+/-0.003) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.815 (+/-0.006) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (100,), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
mlp = MLPClassifier(activation='relu', alpha=0.05, hidden_layer_sizes=(50, 100, 50), learning_rate='adaptive', solver='adam' )

# %%
clf.best_score_
# Out:
# 0.8170276836738185

# %% [markdown]
# Notes:
#
# After hyperparameter tuning, the results are not much different, XGboost is slightly better than MLP. The increase in accuracy score is not very significant.

# %% [markdown]
# ### Confusion Matrix after hyperparameter tuning

# %%
from sklearn.metrics import confusion_matrix, classification_report
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_pred)) , annot=True, fmt='.0f')
# Out:
# <Axes: >

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      5879
#            1       0.85      0.82      0.83      7109
#
#     accuracy                           0.82     12988
#    macro avg       0.82      0.82      0.82     12988
# weighted avg       0.82      0.82      0.82     12988

# %%
from sklearn.metrics import roc_curve, roc_auc_score

xgb_probs_hpt = model.predict_proba(X_test_scaled)
random_probs = [0 for _ in range(len(y_test))]

# %%
xgb_probs_hpt = xgb_probs_hpt[:,1]

# %%
# Calculate AUC for a random model
random_auc = roc_auc_score(y_test, random_probs)
 
# Calculate AUC for a XGBoost classifier
xgb_hpt_auc = roc_auc_score(y_test, xgb_probs_hpt)
 
# Show the rersult:
print('Random Prediction : AUCROC = %.3f' % (random_auc))
print('XGBoost : AUCROC = %.3f' % (xgb_hpt_auc))
# Out:
# Random Prediction : AUCROC = 0.500
# XGBoost : AUCROC = 0.899

# %%
# Stores the values ​​needed to create the ROC curve (false positive rate, true positive rate)
random_fpr, random_tpr, _ = roc_curve(y_test, random_probs)
xgb_fpr, xgb_tpr, _ = roc_curve(y_test, xgb_probs_hpt)
 
# Plot ROC 
plt.plot(random_fpr, random_tpr, marker='.', label='Random : (AUCROC = %.3f)' % random_auc)
plt.plot(xgb_fpr, xgb_tpr, marker='.', label='XGBoost : (AUCROC = %.3f)' % xgb_hpt_auc)
 
plt.title('ROC Plot')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %% [markdown]
# # Artificial Neural Network Using Tensorflow

# %%
from tensorflow import keras
callback = keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# %%
Model=keras.Sequential([keras.layers.Dense(50,activation='relu')
                        ,keras.layers.Dense(100,activation='relu')
                        ,keras.layers.Dense(50,activation='relu'),
                           keras.layers.Dense(1,activation='sigmoid')])

# %%
Model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['acc'])
history=Model.fit(X_train_scaled,y_train,epochs=128,batch_size=32,validation_split=0.1,callbacks=[callback],verbose=1)
# Out:
# Epoch 1/128
# 3288/3288 [==============================] - 7s 2ms/step - loss: 0.4403 - acc: 0.8014 - val_loss: 0.4198 - val_acc: 0.8154
# Epoch 2/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4211 - acc: 0.8109 - val_loss: 0.4151 - val_acc: 0.8163
# Epoch 3/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4165 - acc: 0.8132 - val_loss: 0.4109 - val_acc: 0.8163
# Epoch 4/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4139 - acc: 0.8141 - val_loss: 0.4098 - val_acc: 0.8193
# Epoch 5/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4124 - acc: 0.8144 - val_loss: 0.4080 - val_acc: 0.8163
# Epoch 6/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.4111 - acc: 0.8147 - val_loss: 0.4086 - val_acc: 0.8182
# Epoch 7/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4105 - acc: 0.8151 - val_loss: 0.4070 - val_acc: 0.8186
# Epoch 8/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4096 - acc: 0.8158 - val_loss: 0.4069 - val_acc: 0.8192
# Epoch 9/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.4088 - acc: 0.8171 - val_loss: 0.4056 - val_acc: 0.8204
# Epoch 10/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4078 - acc: 0.8169 - val_loss: 0.4073 - val_acc: 0.8177
# Epoch 11/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4073 - acc: 0.8168 - val_loss: 0.4064 - val_acc: 0.8192
# Epoch 12/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4069 - acc: 0.8169 - val_loss: 0.4063 - val_acc: 0.8166
# Epoch 13/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4067 - acc: 0.8178 - val_loss: 0.4074 - val_acc: 0.8187
# Epoch 14/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.4064 - acc: 0.8184 - val_loss: 0.4034 - val_acc: 0.8207
# Epoch 15/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4056 - acc: 0.8175 - val_loss: 0.4054 - val_acc: 0.8202
# Epoch 16/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4053 - acc: 0.8182 - val_loss: 0.4057 - val_acc: 0.8178
# Epoch 17/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4050 - acc: 0.8181 - val_loss: 0.4050 - val_acc: 0.8197
# Epoch 18/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4046 - acc: 0.8185 - val_loss: 0.4036 - val_acc: 0.8206
# Epoch 19/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.4043 - acc: 0.8187 - val_loss: 0.4059 - val_acc: 0.8188
# Epoch 20/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4039 - acc: 0.8182 - val_loss: 0.4055 - val_acc: 0.8198
# Epoch 21/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.4039 - acc: 0.8178 - val_loss: 0.4046 - val_acc: 0.8193
# Epoch 22/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4035 - acc: 0.8183 - val_loss: 0.4053 - val_acc: 0.8197
# Epoch 23/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4033 - acc: 0.8191 - val_loss: 0.4069 - val_acc: 0.8180
# Epoch 24/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4028 - acc: 0.8190 - val_loss: 0.4048 - val_acc: 0.8198
# Epoch 25/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4025 - acc: 0.8191 - val_loss: 0.4049 - val_acc: 0.8216
# Epoch 26/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4021 - acc: 0.8192 - val_loss: 0.4047 - val_acc: 0.8219
# Epoch 27/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4018 - acc: 0.8189 - val_loss: 0.4070 - val_acc: 0.8180
# Epoch 28/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4018 - acc: 0.8190 - val_loss: 0.4047 - val_acc: 0.8198
# Epoch 29/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4017 - acc: 0.8192 - val_loss: 0.4034 - val_acc: 0.8210
# Epoch 30/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4013 - acc: 0.8193 - val_loss: 0.4062 - val_acc: 0.8198
# Epoch 31/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4010 - acc: 0.8199 - val_loss: 0.4063 - val_acc: 0.8216
# Epoch 32/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4008 - acc: 0.8199 - val_loss: 0.4066 - val_acc: 0.8199
# Epoch 33/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4010 - acc: 0.8197 - val_loss: 0.4048 - val_acc: 0.8196
# Epoch 34/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4008 - acc: 0.8198 - val_loss: 0.4065 - val_acc: 0.8189
# Epoch 35/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.4003 - acc: 0.8204 - val_loss: 0.4068 - val_acc: 0.8176
# Epoch 36/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4004 - acc: 0.8195 - val_loss: 0.4051 - val_acc: 0.8187
# Epoch 37/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.4001 - acc: 0.8201 - val_loss: 0.4056 - val_acc: 0.8224
# Epoch 38/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3998 - acc: 0.8202 - val_loss: 0.4077 - val_acc: 0.8198
# Epoch 39/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3998 - acc: 0.8200 - val_loss: 0.4055 - val_acc: 0.8220
# Epoch 40/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3995 - acc: 0.8202 - val_loss: 0.4046 - val_acc: 0.8187
# Epoch 41/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3996 - acc: 0.8208 - val_loss: 0.4072 - val_acc: 0.8175
# Epoch 42/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3991 - acc: 0.8209 - val_loss: 0.4054 - val_acc: 0.8188
# Epoch 43/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3991 - acc: 0.8205 - val_loss: 0.4056 - val_acc: 0.8210
# Epoch 44/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3986 - acc: 0.8207 - val_loss: 0.4064 - val_acc: 0.8193
# Epoch 45/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3983 - acc: 0.8210 - val_loss: 0.4082 - val_acc: 0.8196
# Epoch 46/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3984 - acc: 0.8210 - val_loss: 0.4052 - val_acc: 0.8198
# Epoch 47/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3979 - acc: 0.8214 - val_loss: 0.4057 - val_acc: 0.8203
# Epoch 48/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3976 - acc: 0.8210 - val_loss: 0.4057 - val_acc: 0.8200
# Epoch 49/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3978 - acc: 0.8206 - val_loss: 0.4065 - val_acc: 0.8188
# Epoch 50/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3973 - acc: 0.8215 - val_loss: 0.4074 - val_acc: 0.8184
# Epoch 51/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3974 - acc: 0.8211 - val_loss: 0.4078 - val_acc: 0.8198
# Epoch 52/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3972 - acc: 0.8212 - val_loss: 0.4072 - val_acc: 0.8203
# Epoch 53/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3969 - acc: 0.8214 - val_loss: 0.4085 - val_acc: 0.8192
# Epoch 54/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3969 - acc: 0.8212 - val_loss: 0.4065 - val_acc: 0.8216
# Epoch 55/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3963 - acc: 0.8218 - val_loss: 0.4086 - val_acc: 0.8179
# Epoch 56/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3964 - acc: 0.8220 - val_loss: 0.4094 - val_acc: 0.8184
# Epoch 57/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3965 - acc: 0.8216 - val_loss: 0.4109 - val_acc: 0.8198
# Epoch 58/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3958 - acc: 0.8218 - val_loss: 0.4084 - val_acc: 0.8199
# Epoch 59/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3962 - acc: 0.8222 - val_loss: 0.4097 - val_acc: 0.8192
# Epoch 60/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3959 - acc: 0.8217 - val_loss: 0.4115 - val_acc: 0.8184
# Epoch 61/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3958 - acc: 0.8220 - val_loss: 0.4096 - val_acc: 0.8160
# Epoch 62/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3957 - acc: 0.8213 - val_loss: 0.4090 - val_acc: 0.8190
# Epoch 63/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3950 - acc: 0.8220 - val_loss: 0.4096 - val_acc: 0.8206
# Epoch 64/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3952 - acc: 0.8225 - val_loss: 0.4088 - val_acc: 0.8202
# Epoch 65/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3948 - acc: 0.8228 - val_loss: 0.4099 - val_acc: 0.8177
# Epoch 66/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3950 - acc: 0.8217 - val_loss: 0.4109 - val_acc: 0.8176
# Epoch 67/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3945 - acc: 0.8221 - val_loss: 0.4095 - val_acc: 0.8187
# Epoch 68/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3938 - acc: 0.8231 - val_loss: 0.4127 - val_acc: 0.8186
# Epoch 69/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3942 - acc: 0.8230 - val_loss: 0.4131 - val_acc: 0.8168
# Epoch 70/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3940 - acc: 0.8225 - val_loss: 0.4126 - val_acc: 0.8163
# Epoch 71/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3938 - acc: 0.8229 - val_loss: 0.4126 - val_acc: 0.8182
# Epoch 72/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3931 - acc: 0.8233 - val_loss: 0.4101 - val_acc: 0.8199
# Epoch 73/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3931 - acc: 0.8226 - val_loss: 0.4145 - val_acc: 0.8166
# Epoch 74/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3932 - acc: 0.8229 - val_loss: 0.4142 - val_acc: 0.8165
# Epoch 75/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3929 - acc: 0.8236 - val_loss: 0.4168 - val_acc: 0.8188
# Epoch 76/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3929 - acc: 0.8233 - val_loss: 0.4131 - val_acc: 0.8170
# Epoch 77/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3925 - acc: 0.8233 - val_loss: 0.4134 - val_acc: 0.8166
# Epoch 78/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3923 - acc: 0.8237 - val_loss: 0.4157 - val_acc: 0.8180
# Epoch 79/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3927 - acc: 0.8235 - val_loss: 0.4149 - val_acc: 0.8159
# Epoch 80/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3923 - acc: 0.8235 - val_loss: 0.4132 - val_acc: 0.8189
# Epoch 81/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3919 - acc: 0.8236 - val_loss: 0.4129 - val_acc: 0.8140
# Epoch 82/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3921 - acc: 0.8231 - val_loss: 0.4152 - val_acc: 0.8174
# Epoch 83/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3914 - acc: 0.8239 - val_loss: 0.4122 - val_acc: 0.8162
# Epoch 84/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3916 - acc: 0.8236 - val_loss: 0.4146 - val_acc: 0.8199
# Epoch 85/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3911 - acc: 0.8239 - val_loss: 0.4154 - val_acc: 0.8186
# Epoch 86/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3915 - acc: 0.8234 - val_loss: 0.4142 - val_acc: 0.8177
# Epoch 87/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3909 - acc: 0.8245 - val_loss: 0.4156 - val_acc: 0.8169
# Epoch 88/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3910 - acc: 0.8245 - val_loss: 0.4146 - val_acc: 0.8193
# Epoch 89/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3908 - acc: 0.8240 - val_loss: 0.4177 - val_acc: 0.8163
# Epoch 90/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3904 - acc: 0.8245 - val_loss: 0.4166 - val_acc: 0.8169
# Epoch 91/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3906 - acc: 0.8241 - val_loss: 0.4145 - val_acc: 0.8159
# Epoch 92/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3904 - acc: 0.8242 - val_loss: 0.4145 - val_acc: 0.8178
# Epoch 93/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3904 - acc: 0.8249 - val_loss: 0.4175 - val_acc: 0.8158
# Epoch 94/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3901 - acc: 0.8248 - val_loss: 0.4164 - val_acc: 0.8169
# Epoch 95/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3894 - acc: 0.8249 - val_loss: 0.4181 - val_acc: 0.8174
# Epoch 96/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3894 - acc: 0.8255 - val_loss: 0.4149 - val_acc: 0.8182
# Epoch 97/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3895 - acc: 0.8244 - val_loss: 0.4185 - val_acc: 0.8163
# Epoch 98/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3892 - acc: 0.8246 - val_loss: 0.4174 - val_acc: 0.8156
# Epoch 99/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3894 - acc: 0.8241 - val_loss: 0.4152 - val_acc: 0.8170
# Epoch 100/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3886 - acc: 0.8258 - val_loss: 0.4193 - val_acc: 0.8165
# Epoch 101/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3888 - acc: 0.8247 - val_loss: 0.4167 - val_acc: 0.8169
# Epoch 102/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3884 - acc: 0.8250 - val_loss: 0.4169 - val_acc: 0.8161
# Epoch 103/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3882 - acc: 0.8250 - val_loss: 0.4192 - val_acc: 0.8156
# Epoch 104/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3883 - acc: 0.8253 - val_loss: 0.4221 - val_acc: 0.8156
# Epoch 105/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3882 - acc: 0.8249 - val_loss: 0.4204 - val_acc: 0.8147
# Epoch 106/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3883 - acc: 0.8255 - val_loss: 0.4170 - val_acc: 0.8172
# Epoch 107/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3879 - acc: 0.8252 - val_loss: 0.4182 - val_acc: 0.8174
# Epoch 108/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3880 - acc: 0.8250 - val_loss: 0.4175 - val_acc: 0.8159
# Epoch 109/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3877 - acc: 0.8263 - val_loss: 0.4178 - val_acc: 0.8158
# Epoch 110/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3872 - acc: 0.8260 - val_loss: 0.4198 - val_acc: 0.8149
# Epoch 111/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3872 - acc: 0.8255 - val_loss: 0.4218 - val_acc: 0.8163
# Epoch 112/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3874 - acc: 0.8261 - val_loss: 0.4192 - val_acc: 0.8167
# Epoch 113/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3872 - acc: 0.8257 - val_loss: 0.4162 - val_acc: 0.8170
# Epoch 114/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3870 - acc: 0.8258 - val_loss: 0.4252 - val_acc: 0.8161
# Epoch 115/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3866 - acc: 0.8256 - val_loss: 0.4197 - val_acc: 0.8152
# Epoch 116/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3865 - acc: 0.8261 - val_loss: 0.4218 - val_acc: 0.8148
# Epoch 117/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3866 - acc: 0.8261 - val_loss: 0.4209 - val_acc: 0.8190
# Epoch 118/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3862 - acc: 0.8261 - val_loss: 0.4210 - val_acc: 0.8151
# Epoch 119/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3863 - acc: 0.8266 - val_loss: 0.4225 - val_acc: 0.8143
# Epoch 120/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3859 - acc: 0.8259 - val_loss: 0.4227 - val_acc: 0.8177
# Epoch 121/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3860 - acc: 0.8260 - val_loss: 0.4240 - val_acc: 0.8152
# Epoch 122/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3859 - acc: 0.8265 - val_loss: 0.4275 - val_acc: 0.8175
# Epoch 123/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3861 - acc: 0.8264 - val_loss: 0.4248 - val_acc: 0.8137
# Epoch 124/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3859 - acc: 0.8262 - val_loss: 0.4218 - val_acc: 0.8151
# Epoch 125/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3859 - acc: 0.8260 - val_loss: 0.4252 - val_acc: 0.8147
# Epoch 126/128
# 3288/3288 [==============================] - 6s 2ms/step - loss: 0.3853 - acc: 0.8265 - val_loss: 0.4245 - val_acc: 0.8179
# Epoch 127/128
# 3288/3288 [==============================] - 5s 1ms/step - loss: 0.3852 - acc: 0.8268 - val_loss: 0.4260 - val_acc: 0.8133
# Epoch 128/128
# 3288/3288 [==============================] - 5s 2ms/step - loss: 0.3853 - acc: 0.8267 - val_loss: 0.4220 - val_acc: 0.8145

# %%
def plot_graphs(history,string):
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()
  
plot_graphs(history, "acc")
plot_graphs(history, "loss")

# %%
y_pred_deep=Model.predict(X_test_scaled)
# Out:
# 406/406 [==============================] - 0s 940us/step

# %%
sns.heatmap(pd.DataFrame(confusion_matrix(y_test,y_pred_deep.round())) , annot=True, fmt='.0f')
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred_deep.round()))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.80      5879
#            1       0.84      0.82      0.83      7109
#
#     accuracy                           0.82     12988
#    macro avg       0.82      0.82      0.82     12988
# weighted avg       0.82      0.82      0.82     12988

# %% [markdown]
# Notes:
#
# ANN using tensorflow the results are not much different. This means to improve the model only by training with even better data. Maybe retraining can be done again after getting new data from the production environment.

# %%
import pickle
pickle.dump(model, open('deep.pkl','wb'))
